# %% [markdown]
# # Introduction to Text Mining Part 2 - Exercises

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# #### Task 1
# ##### Load the libraries that are used in this module.

# %% [markdown]
# #### Result:

# %%
from pathlib import Path
# Set `home_dir` to the root directory of your computer. 
home_dir = Path.home()

# Set `main_dir` to the location of your `booz-allen-hamilton` folder.
main_dir = home_dir / "Documents" / "NLP_Intro" / "intro-to-text-mining-main"

# Make `data_dir` from the `main_dir` and remainder of the path to data directory.
data_dir = main_dir / "data"

import os
# Set working directory.
os.chdir(data_dir)

# Check working directory.
print(os.getcwd())
# Helper packages.
import os
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

# Packages with tools for text processing.
import nltk
import nltk.data
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer
from wordcloud import WordCloud
# Out:
# /Users/amirmokhtari/Documents/NLP_Intro/intro-to-text-mining-main/data

# %% [markdown]
# #### Task 2
# ##### Set `main_dir` to the location of your `booz-allen-hamilton` folder.
# ##### Make `data_dir` from the `main_dir` and concatenate remainder of the path to data directory.

# %% [markdown]
# #### Result:

# %%
print(os.getcwd())
# Out:
# /Users/amirmokhtari/Documents/NLP_Intro/intro-to-text-mining-main/data

# %% [markdown]
# #### Task 3
# ##### Set the working directory to `data_dir`.
# ##### Check if the working directory is updated to `data_dir`.

# %% [markdown]
# #### Result:

# %% [markdown]
# #### Task 4
# ##### Load the pickled files from the previous exercises: `ex_titles_clean.sav`, `ex_corpus_freq_dist` and `ex_titles_clean_list`.
# ##### Save them as `processed_docs_ex`, `ex_corpus_freq_dist` and `titles_clean_list`.

# %% [markdown]
# #### Result:

# %%
processed_docs_ex = pickle.load(open("ex_titles_clean.sav","rb"))
ex_corpus_freq_dist = pickle.load(open("ex_corpus_freq_dist.sav","rb"))
titles_clean_list = pickle.load(open("ex_titles_clean_list.sav","rb"))

# %%
ex_corpus_freq_dist
# Out:
# FreqDist({'agreement': 1085, 'exchang': 386, 'constitut': 334, 'note': 324, 'amend': 256, 'unit': 203, 'concern': 175, 'annex': 167, 'govern': 161, 'loan': 143, ...})

# %% [markdown]
# #### Task 5
# ##### Plot the frequency distribution of words in `ex_corpus_freq_dist` .

# %%
ex_corpus_freq_dist
# Out:
# FreqDist({'agreement': 1085, 'exchang': 386, 'constitut': 334, 'note': 324, 'amend': 256, 'unit': 203, 'concern': 175, 'annex': 167, 'govern': 161, 'loan': 143, ...})

# %% [markdown]
# #### Result:

# %%
corpus_freq_dist = nltk.FreqDist(ex_corpus_freq_dist)

# %%
plt.figure(figsize = (50, 10))
corpus_freq_dist.plot(80)

# %% [markdown]
# #### Task 6
# ##### Create a word cloud of the entire corpus and name it `ex_wordcloud`.
# ##### Plot the wordcloud and set `figsize` to` (14, 7)`.

# %% [markdown]
# #### Result:

# %%
titles_clean_list
# Out:
# ['agreement concern arrang hold fifth session council unit nation relief rehabilit administr palai de nation geneva conclud unit nation leagu nation unit nation relief rehabilit administr',
#  'declar recogn compulsori jurisdict court conform articl paragraph statut intern court justic legal disput concern interpret applic valid treati relat boundari british hondura london februari',
#  'declar renew period five year begin februari declar recogn compulsori jurisdict court conform articl paragraph statut intern court justic legal disput concern interpret applic valid treati relat boundari british hondura london februari',
#  'declar recogn compulsori jurisdict court conform articl paragraph statut intern court justic new york decemb',
#  'convent unit kingdom franc respect commerci relat franc seychel island sign london april denunci part unit kingdom',
#  'exchang note constitut agreement amend supplementingth agreement amend washington decemb januari',
#  'exchang note constitut agreement amend air transport agreement govern unit state america govern commonwealth australia',
#  'exchang note constitut agreement amend agreement decemb amend',
#  'exchang note constitut agreement amend agreement amend',
#  'exchang note constitut agreement amend agreement decemb amend',
#  'geodet survey agreement',
#  'exchang note constitut agreement establish naha advisori committe high commission ryukyu island tokyo januari',
#  'exchang note constitut agreement amend agreement januari amend montevideo april',
#  'exchang note constitut agreement amend agreement memorandum understand montevideo june',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement amend agreement montevideo march',
#  'exchang note constitut agreement establish clark air base commerci branch philippin bank relat unit state treasuri facil clark field air base sangley point navi base manila januari',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement econom technic dar es salaam februari',
#  'exchang note constitut agreement concern furnish reimburs basi certain servic materi peculiar type air navig aid use ministri govern justic panama panama decemb februari',
#  'invest guaranti agreement',
#  'agreement sale agricultur commod',
#  'parcel post agreement',
#  'agreement govern iraq govern pakistan relat air servic',
#  'exchang note constitut agreement amend annex agreement govern iraq govern pakistan relat air servic',
#  'memorandum understand cooper assist',
#  'agreement develop water resourc iran',
#  'agreement sale agricultur commod',
#  'exchang letter constitut agreement relat deploy uss shenandoah malta valleta april',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement relat mutual assist event natur disast washington may',
#  'exchang note constitut agreement amend agreement',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement relat extens custom free entri privileg consular offic either countri station territori countri washington may',
#  'exchang note constitut agreement relat reciproc grant authoris permit licens amateur radio oper either countri oper station countri georgetown may',
#  'exchang note constitut agreement relat peac corp bridgetown april montserrat may',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement modifi agreement govern new zealand govern canada relat air transport',
#  'agreement govern new zealand govern canada relat air transport',
#  'convent avoid doubl taxat regul certain matter respect tax incom fortun',
#  'convent provid reciproc recognit enforc judgment civil matter',
#  'exchang note constitut agreement extend guernsey jersey isl man convent hagu decemb',
#  'exchang note constitut agreement relat extens surinam netherland antil convent london septemb',
#  'exchang note constitut agreement extend hong kong convent hagu novemb',
#  'convent govern unit kingdom great britain northern ireland govern republ south africa avoid doubl taxat prevent fiscal evas respect tax incom capit gain',
#  'exchang note constitut agreement amend agreement april amend',
#  'exchang note constitut agreement concern abolit visa',
#  'exchang note constitut agreement amend agreement belgrad februari march',
#  'exchang note constitut agreement concern interim arrang offset foreign exchang expenditur british forc feder republ germani bonn may',
#  'long term trade agreement',
#  'exchang note concern develop loan govern unit kingdom great britain northern ireland govern republ turkey unit loan ankara june',
#  'exchang letter constitut agreement concern instal telemetri station fortaleza pari may june',
#  'agreement govern kingdom netherland govern republ chile concern migrat',
#  'exchang note constitut agreement govern greec itali relat greek cultur institut itali italian cultur institut greec',
#  'consular convent protocol',
#  'agreement avoid doubl taxat incom deriv maritim air transport oper',
#  'agreement concern transport good road',
#  'convent social secur',
#  'exchang note constitut agreement concern tax relief motor vehicl engag intern road transport pari march',
#  'exchang note constitut agreement concen develop loan govern unit kingdom great britain northern ireland thegovern republ indonesia unit loan annex relat note djakarta april',
#  'exchang note constitut agreement amend agreement djakarta march april',
#  'exchang note amend headquart agreement govern unit kingdom great britain northern ireland intern coffe organ',
#  'exchang note constitut agreement amend agreement london may',
#  'headquart agreement govern unit kingdom great britain northern ireland intern coffe organ',
#  'exchang note amend headquart agreement govern unit kingdom great britain northern ireland intern sugar organ',
#  'exchang note constitut agreement amend agreement london januari',
#  'headquart agreement govern unit kingdom great britain northern ireland intern sugar organ',
#  'exchang note constitut agreement concern provis personnel unit kingdom arm forc assist staf administr train arm forc kenya nairobi novemb',
#  'commerci agreement kingdom greec econom union',
#  'agreement concern peac use atom energi',
#  'protocol exchang teacher student specialist scientif worker higher educ establish period helsinki may',
#  'agreement econom industri technic',
#  'exchang note constitut agreement relat invest guaranti managua may',
#  'consular convent protocol exchang letter',
#  'exchang note constitut agreement coordin effort geodet survey along parallel arc across territori upper volta ouagadoug june august',
#  'exchang note constitut agreement concern trade cotton textil belgrad septemb',
#  'exchang note constitut agreement amend extend agreement amend extend washington june',
#  'exchang note constitut agreement amend extend agreement washington decemb',
#  'exchang note constitut agreement concern trade cotton textil annex relat note washington octob',
#  'exchang note constitut agreement relat mutual defens assist tokyo octob',
#  'exchang note constitut agreement concern trade cotton textil washington octob',
#  'exchang note constitut agreement amend extend agreement washington decemb',
#  'payment agreement greek govern belgian govern',
#  'agreement sale agricultur commod',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement loan addit long rang aid navig equip ottawa juli octob',
#  'agreement sale agricultur commod',
#  'supplementari agreement sale agricultur commod',
#  'exchang note constitut agreement relat invest guaranti bathurst juli novemb',
#  'agreement sale agricultur commod',
#  'agreement certain fisheri problem high sea western area middl atlant ocean',
#  'agreement extend modifi agreement',
#  'exchang note constitut agreement reciproc grant authorizaton permit licens amateur radio oper either countri oper station countri washington novemb',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement amend extend agreement washington decemb',
#  'exchang note constitut agreement supersed agreement januari amend except exchang letter date novemb concern trade cotton textil washington decemb',
#  'exchang note constitut agreement amend extend agreement amend extend washington june',
#  'agreement sale agricultur commod',
#  'agreement use certain unit state new taiwan dollar accru titl agricultur trade develop assist act amend decemb',
#  'exchang note constitut agreement relat peac corp bridgetown decemb grenada decemb',
#  'exchang note constitut agreement amend agreement la paz februari april',
#  'agreement sale agricultur commod',
#  'supplementari agreement sale agricultur commod',
#  'agreement sale agricultur commod',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement establish programm known oceanograph meteorolog experi bomex bridgetown june juli',
#  'agreement exchang scientif technic educ cultur field',
#  'exchang letter constitut agreement relat agreement vienna april moscow may',
#  'payment agreement royal govern greec militari govern germani french unit state unit kingdom cover payment trade french unit state unit kingdom occupi area germani greec',
#  'supplementari agreement sale agricultur commod',
#  'supplementari agreement sale agricultur commod',
#  'supplementari agreement sale agricultur commod',
#  'exchang note constitut agreement amend agreement tokyo septemb',
#  'exchang note constitut agreement regard establish oper satellit track station okinawa tokyo septemb',
#  'exchang note constitut agreement extend agreement extend washington decemb',
#  'exchang note constitut agreement research remot sens earth survey rio de janeiro januari septemb',
#  'exchang note constitut agreement reciproc grant author permit licens amateur radio oper either countri oper station countri bridgetown septemb',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement concern trade cotton textil washington septemb',
#  'exchang note constitut agreement regard establish direct commun channel appropri author two govern common problem maritim transport rio de janeiro septemb',
#  'exchang noe constitut agreement concern duti certif implement articl vii paragraph ii agreement parti north atlant treati regard statu forc ankara septemb',
#  'agreement transfer asset',
#  'trade agreement royal govern greec govern finland',
#  'third addit protocol trade agreement royal govern greec govern finland',
#  'fourth addit protocol trade agreement royal govern greec govern finland',
#  'exchang note constitut agreement relat deploy uss everglad malta valetta septemb',
#  'invest guaranti agreement',
#  'invest guaranti agreement',
#  'exchang note constitut agreement termin commerci agreement januari relat agreement supplement otherwis affect washington octob',
#  'exchang note constitut agreement concern establish joint committe state cultur educ cooper tokyo novemb',
#  'exchang note constitut agreement amend agreement tokyo februari',
#  'exchang note constitut agreement dispos unit state excess person properti possess militari author govern unit state saigon novemb',
#  'exchang note constitut agreement concern extens loan vessel uss bergal turkey ankara novemb',
#  'invest guaranti agreement',
#  'convent kingdom netherland grand duchi luxembourg avoid doubl taxat prevent fiscal evas respect tax incom fortun',
#  'protocol convent kingdom netherland grand duchi luxembourg avoid doubl taxat prevent fiscal evas respect tax incom fortun sign hagu may',
#  'loan agreement hous financ sector project',
#  'payment agreement royal govern greec govern finland',
#  'convent social secur',
#  'addit agreement agreement decemb',
#  'third addit convent convent decemb',
#  'agreement implement convent',
#  'addit convent convent',
#  'second addit convent',
#  'loan agreement seyhan irrig ii annex gener condit applic loan guarante agreement',
#  'develop credit agreement seyhan irrig ii annex gener condit applic develop credit agreement',
#  'loan agreement third telecommun project annex gener condit applic loan guarante agreement',
#  'develop credit agreement third telecommun project annex gener condit applic develop credit agreement',
#  'treati brotherhood relat',
#  'loan agreement educ project annex loan regul amend',
#  'develop credit agreement educ project annex credit regul amend',
#  'guarante agreement second sui northern ga project annex gener condit applic loan guarante agreement loan agreement sui northern ga pipelin limit bank',
#  'agreement deal pollut north sea oil',
#  'extradit treati great britain sweden norway',
#  'declar recogn compulsori jurisdict court conform articl paragraph statut intern court justic',
#  'agreement annex protocol',
#  'protocol liquid greec turkey',
#  'protocol order make possibl transfer receipt turkish air ship line acquir prior entri forc payment agreement april',
#  'payment agreement greec turkey',
#  'agreement establish food fertilis technolog centr asian pacif region',
#  'agreement cultur technic scientif',
#  'protocol agreement concern french institut orient archaeolog cairo',
#  'loan agreement agricultur credit project annex gener condit applic loan guarante agreement',
#  'guarante agreement third develop corpor project annex gener condit applic loan guarante agreement bank loan agreement bank philippin nation bank project agreement bank privat develop corpor philippin',
#  'convent offenc certain act commit board aircraft',
#  'guarante agreement volta expans project annex gener condit applic loan guarante agreement bank loan agreement bank volta river author',
#  'protocol amend benelux uniform law mark',
#  'protocol relat benelux convent trade mark',
#  'second protocol amend regul benelux uniform law respect trade mark annex protocol juli conclud applic articl benelux convent march trade mark',
#  'protocol amend regul benelux uniform law respect trade mark annex protocol juli conclud applic articl benelux convent march trade mark',
#  'protocol conclud applic articl benelux convent trade mark',
#  'protocol amend benelux uniform law mark',
#  'benelux convent trade mark',
#  'protocol modifi benelux uniform law trade mark annex benelux convent trade mark',
#  'protocol amend benelux uniform law mark',
#  'agreement feder republ germani kingdom belgium avoid doubl taxat regul certain matter respect tax incom fortun includ busi tax land tax',
#  'addit agreement agreement april feder republ germani kingdom belgium avoid doubl taxat regul certain matter respect tax incom fortun includ busi tax land tax final protocol',
#  'gener convent social secur',
#  'treati friendship mutual assist',
#  'loan agreement fisheri project annex loan regul amend project agreement bank corporacion financiera nacion',
#  'agreement amend loan agreement fisheri project septemb republ ecuador intern bank reconstruct develop',
#  'agreement amend loan agreement fisheri project septemb republ ecuador intern bank reconstruct develop amend',
#  'letter agreement amend loan agreement fisheri project septemb republ ecuador intern bank reconstruct develop amend',
#  'letter agreement amend loan agreement fisheri project septemb republ ecuador intern bank reconstruct develop amend',
#  'letter agreement amend loan agreement fisheri project republ ecuador intern bank reconstruct develop',
#  'guarante agreement fifth industri develop bank project annex gener condit applic loan guarante agreement bank loan agreementbetween bank turkiy sinai kalkinma bankasi',
#  'exchang note constitut agreement concern develop loan govern unit kingdom govern jordan amman',
#  'exchang note constitut agreement concern develop loan govern unit kingdom govern jordan amman may',
#  'exchang note constitut agreement amend agreement djakarta march april',
#  'exchang note constitut agreement concern develop loan govern unit kingdom govern indonesia unit loan annex addit note djakarta june',
#  'exchang note constitut agreement concern loan toward cost prek thnot cambodia power irrig develop project prek thnot loan phnom penh juli',
#  'exchang note constitut agreement concern guarante govern unit kingdom mainten minimum sterl proport western samoa wellington apia juli',
#  'loan agreement highway construct project annex loan regul amend',
#  'protocol liquid asset',
#  'loan agreement agricultur credit project annex loan regul amend',
#  'develop credit agreement agricultur credit project annex credit regul amend',
#  'guarante agreement douala water suppli project annex gener condit applic loan guarante agreement bank loan agreementbetween bank national de eaux du cameroun',
#  'agreement relat air servic',
#  'exchang note constitut agreement secur social secur benefit philippin citizen civilian employe agenc intern develop mission philippin manila novembr march',
#  'exchang note constitut agreement secur social secur benefit philippin citizen civilian employe peac corp joint militari advisori group jusmag manila april juli',
#  'exchang note constitut agreement use special fund educ school build construct project annex relat note april manila may',
#  'exchang note constitut agreement use special fund educ textbook product project annex relat note april manila june',
#  'exchang note constitut agreement use special fund educ cultur develop project annex relat note april manila august',
#  'exchang note constitut agreement concern relinquish certain unit state base land philippin manila april',
#  'assign agreement fourth caribbean develop bank region vocat technic educ project',
#  'agreement royal hellen govern govern syrian republ relat civil air servic respect territori',
#  'exchang note constitut agreement use special fund educ fund assist privat educ annex relat note april manila',
#  'agreement concern civil use atom energi',
#  'exchang note constitut agreement unit state assist undertak artifici rain stimul project manila april',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement transfer titl uss charl ausburn feder republ germani bonn bad godesberg februari',
#  'supplementari agreement sale agricultur commod',
#  'supplementari agreement sale agricultur commod',
#  'supplementari agreement sale agricultur commod',
#  'exchang note constitut agreement extablish program oper mainten network rawinsond observ station brazil rio de janeiro march',
#  'supplementari agreement sale agricultur commod',
#  'agreement itali greec econom collabor settlement question aris treati peac alli associ power itali',
#  'develop credit agreement fourth caribbean develop bank region vocat technic educ project',
#  'exchang letter constitut supplementari agreement protocol athen march',
#  'protocol revok part ii iii agreement itali greec econom collabor settlement question aris treati peac alli associ power itali french titl',
#  'supplementari agreement sale agricultur commod',
#  'supplementari agreement sale agricultur commod',
#  'exchang note constitut agreement amend agreement seoul may',
#  'supplementari agreement sale agricultur commod',
#  'exchang note constitut agreement relat peac corp managua may',
#  'exchang note constitut agreement concern seismic array research plan util seismic array facil instal oper norway oslo june',
#  'exchang note constitut agreement relat loan vessel yarnal republ china taipei june',
#  'exchang note constitut agreement regard gift facil produc potabl water madrid june',
#  'exchang note constitut agreement amend agreement sign kabul februari march',
#  'supplementari agreement sale agricultur commod',
#  'exchang note constitut agreement concern establish principl scientif tuni juli',
#  'loan agreement kyonggi region transport project',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement reciproc grant author permit licens amateur radio oper either countri oper station decemb',
#  'agreement sale agricultur commod',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement amend la paz march april',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement concern assist geolog studi regard sea level canal site along rout bella panama march',
#  'exchang note constitut agreement acquisit product japan aircraft relat equip materi necessari enhanc defens capabl japan tokyo april',
#  'exchang note constitut agreement concern trade cotton textil athen april',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement continu cooper program oper rawinsond observ station santo domingo santo domingo april',
#  'convent concern age admiss children employ revis modifi final articl revis convent',
#  'supplementari agreement sale agricultur commod',
#  'agreement establish schedul air servic beyond respect territori',
#  'agreement regard far east pacif offic said organ',
#  'convent concern public assist juvenil welfar final protocol appendic sigend bonn januari',
#  'agreement implement convent',
#  'agreement air servic beyond respect territori',
#  'agreement concern air servic',
#  'agreement relat air servic',
#  'exchang note constitut agreement modifi agreement singapor octob march',
#  'agreement relat air servic',
#  'agreement relat air servic republ south africa belgium',
#  'loan agreement educ project annex gener condit applic loan guarante agreement',
#  'convent concern medic examin fit employ industri children young person',
#  'agreement technic cooper',
#  'agreement provis oper execut personnel',
#  'agreement govern commonwealth australia govern republ singapor avoid doubl taxat prevent fiscal evas respect tax incom',
#  'protocol amend agreement februari exchang note date octob',
#  'exchang note constitut agreement extend agreement canberra may',
#  'exchang note constitut agreement amend agreement februari amend extend',
#  'exchang note constitut agreement visa visa fee london april',
#  'exchang note constitut agreement relat issu grati visa visitor canberra juli',
#  'agreement regard loan kingdom denmark ivori coast annex exchang note',
#  'guarante agreement third technolog develop project',
#  'convent concern medic examin children young person fit employ occup',
#  'agreement schedul air transport',
#  'agreement field peac use nuclear energi',
#  'agreement invest industri complementar',
#  'agreement field peac use nuclear energi',
#  'agreement concern bridg',
#  'cultur agreement argentin republ republ korea',
#  'exchang note constitut agreement concern establish jean mermoz cultur foundat bueno air march',
#  'basic agreement scientif research technolog develop',
#  'exchang letter constitut agreement implement agreement bueno air decemb',
#  'trade agreement argentin republ republ romania',
#  'convent concern restrict night work children young person occup',
#  'convent foreign exchang control',
#  'interpret convent note secretariat',
#  'exchang note constitut agreement concern studi expert facilit plan develop electr servic argentin littor bueno air may',
#  'exchang note constitut agreement polici view market meat bueno air june',
#  'exchang note constitut agreement extend credit uruguayan govern suppli argentin beef bueno air septemb',
#  'agreement regul channel dredg buoyag mainten river paraguay',
#  'agreement concern film film product',
#  'agreement concern financi assist gener survey ibera system river plate basin bueno air octob',
#  'exchang letter constitut agreement concern implement netherland volunt programm india new delhi juli',
#  'convent avoid doubl taxat prevent fiscal evas respect tax incom capit',
#  'loan agreement dez irrig annex loan regul amend',
#  'exchang note amend air transport agreement govern republ philippin govern republ korea',
#  'air transport agreement',
#  'convent intern civil aviat',
#  'protocol relat trade period novemb octob',
#  'agreement regard danish govern loan annex exchang letter',
#  'agreement regard danish govern loan annex exchang letter memorandum',
#  'standard agreement oper assist sign new york januari',
#  'agreement view use mainten administr dispos properti facil',
#  'agreement concern intern road transport',
#  'trade econom agreement annex schedul protocol',
#  'agreement concern intern road transport',
#  'trade agreement annex schedul',
#  'agreement concern cultur scientif',
#  'convent prevent punish crime genocid',
#  'technic assist financ agreement food grain research develop program farm system research',
#  'agreement concern cultur',
#  'convent concern matter plant protect quarantin',
#  'loan agreement educ project annex loan regul amend',
#  'develop credit agreement telecommun project annex credit regul amend project agreement associ offic de post et de',
#  'develop credit agreement hinvi agricultur develop project annex credit regul amend project agreement associ national pour le rural du dahomey',
#  'memorandum understand concern hinvi agricultur develop project',
#  'develop credit agreement coffe improv project annex credit regul amend',
#  'guarante agreement finchaa hydroelectr project annex gener condit applic loan guarante agreement loan agreement bank ethiopian electr light power author',
#  'loan agreement rural credit project',
#  'letter amend loan agreement rural credit project kingdom tonga intern fund agricultur develop',
#  'trade agreement royal govern denmark royal govern greec',
#  'guarante agreement power transmiss distribut project annex loan regul amend loan agreement bank trinidad tobago electr commiss',
#  'loan agreement third highway project annex gener condit applic loan guarante agreement',
#  'guarante agreement pump storag power project annex loan regul amend loan agreement bank electr suppli board',
#  'develop credit agreement highway project annex gener condit applic develop credit agreement',
#  'develop credit agreement second educ project annex credit regul amend',
#  'loan agreement third livestock project annex gener condit applic loan guarante agreement',
#  'develop credit agreement third livestock project annex gener condit applic develop credit agreement',
#  'develop credit agreement third agricultur develop bank project annex gener condit applic develop credit agreement project agreement theassoci agricultur develop bank pakistan',
#  'cultur agreement franc brazil',
#  'exchang letter constitut agreement concern privileg accord brazil french personnel engag programm rio de janeiro januari',
#  'basic cooper agreement',
#  'addit protocol payment agreement royal govern denmark royal govern greec',
#  'payment agreement royal govern denmark royal govern greec',
#  'agreement technic scientif govern french republ govern unit state brazil',
#  'amend amend agreement sign brasilia march',
#  'exchang letter constitut agreement concern instal telemetri station forlateza rio de janeiro june',
#  'agreement establish caribbean develop bank',
#  'exchang letter constitut agreement supplement modifi annex b convent pari may februari',
#  'convent protect appel origin indic sourc design certain product protocol annex',
#  'exchang note constitut gener fisheri agreement pari march',
#  'develop credit agreement second end power project annex credit regul amend project agreement associ empresa nacion de electricidad',
#  'agreement peac use atom energi sign santiago novemb',
#  'exchang note constitut agreement concern financi assist unit kingdom nepal toward construct secondari school boy unit financi agreement kathmandu august',
#  'exchang note constitut agreement amend agreement katmandu april januari',
#  'exchang note constitut agreement concern particip unit kingdom foreign exchang oper fund lao vientian august',
#  'exchang note constitut agreement relat cereal london august',
#  'trade agreement denmark itali',
#  'guarante agreement taegu urban transport project',
#  'exchang letter constitut agreement prolong modif agreement gaboron septemb',
#  'exchang letter constitut agreement concern guarante unit kingdom mainten reserv sterl govern botswana gaboron septemb',
#  'agreement offset foreign exchang expenditur british forc feder republ germani',
#  'protocol concern return brigad feder republ germani supplement agreement bonn septemb',
#  'exchang note constitut agreement concern develop loan govern unit kingdom great britain northern ireland govern republ turkey unit loan ankara septemb',
#  'exchang note constitut agreement concern reciproc payment social secur pension london septemb',
#  'tax agreement protocol exchang letter',
#  'exchang letter constitut agreement unit nation mauritiu applic unit nation govern mauritiu agreement juli unit nation govern unit kingdom great britain northern ireland provis technic assist trust territori whose intern relat govern unit kingdom respons',
#  'exchang letter constitut agreement applic unit nation develop programm special fund govern mauritiu agreement januari govern unit kingdom great britain northern ireland unit nation special fund concern assist special fund new york may august',
#  'exchang note constitut agreement rel extend free entri privileg philippin depend unit state personnel assign south manila',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement amend agreement santo domingo may',
#  'payment agreement denmark itali',
#  'agreement sale agricultur commod',
#  'agreement sale agricultur commod',
#  'exchang letter constitut agreement modifi agreement amend santo domingo june june',
#  'exchang note constitut agreement expans econom relat tow countri washington juli',
#  'agreement entri defray inland transport charg voluntari agenc suppli equip new delhi decemb',
#  'agreement sale agricultur commod',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement transfer vessel uss geronimo navi republ china taipei decemb',
#  'exchang note constitut agreement continu cooper program oper rawinsond observ station bogota similar station san island bogota decemb',
#  'exchang note constitut agreement amend extend agreement washington june',
#  'exchang note constitut agreement cooper research remot sens earth survey mexico tlatelolco decemb',
#  'exchang note constitut agreement amend agreement new delhi may',
#  'fourth supplementari agreement sale agricultur commod',
#  'exchang note constitut agreement belgium franc concern entri franc algeria belgian nation resid switzerland',
#  'agreement technic implement research project industri complementar',
#  'exchang letter constitut arrang concern trade cotton textil schedul singapor decemb',
#  'agreement sale agricultur commod',
#  'fifth supplementari agreement sale agricultur commod',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement scientif scholarli cooper taipei januari',
#  'exchang note constitut agreement regard applic safeguard unit state natur uranium transfer canada washington januari',
#  'exchang note constitut agreement amend agreement conakri octob',
#  'agreement sale agricultur commod',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement amend agreement ankara juli',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement modifi agreement rabat septemb',
#  'exchang note constitut agreement amend extend agreement amend extend pragu may',
#  'exchang note constitut agreement amend extend agreement amend extend',
#  'exchang note constitut agreement amend extend agreement amend extend pragu may novemb',
#  'agreement unit state america czechoslovak socialist republ extend air transport agreement februari amend extend',
#  'exchang note constitut agreement amend extend agreement amend extend',
#  'agreement unit state america czechoslovak socialist republ extend air transport agreement februari amend extend',
#  'agreement unit state america czechoslovak socialist republ extend air transport agreement februari amend extend',
#  'agreement unit state america czechoslovak socialist republ amend extend agreement februari amend extend concern air transport servic',
#  'exchang note constitut agreement extend agreement amend extend pragu june juli',
#  'exchang letter constitut agreement extend agreement pragu april',
#  'exchang note constitut agreement amend extend agreement amend extend pragu august',
#  'protocol modifi extend agreement extend',
#  'air transport agreement govern unit state america govern czechoslovak socialist republ',
#  'execut agenc agreement annex model standard basic assist agreement',
#  'exchang note constitut agreement construct temporari cofferdam niagara washington march',
#  'exchang note constitut agreement temporari divers power purpos water normal flow american fall niagara washington march',
#  'exchang note constitut agreement regard abolit reciproc basi certain visa fee bucharest april',
#  'agreement sale agricultur commod annex exchang note',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement extend certain deadlin specifi agreement moscow februari',
#  'exchang note constitut agreement extend certain deadlin specifi agreement moscow septemb',
#  'exchang note constitut agreement extend certain deadlin specifi agreement moscou novemb',
#  'exchang note constitut agreement extend certain deadlin specifi agreement amend moscow april',
#  'agreement reciproc alloc use free charg plot land moscow washington annex map exchang note',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement reciproc grant author permit licens amatu radio oper either countri oper station countri stockholm may june',
#  'agreement cultur scientif',
#  'agreement econom technic period',
#  'monetari agreement govern denmark govern unit kingdom great britain northern ireland',
#  'exchang note constitut agreement prolong monetari agreement govern denmark govern unit kingdom great britain northern ireland',
#  'agreement cultur scientif',
#  'agreement cultur scientif exchang govern unit mexican state govern union soviet socialist republ',
#  'agreement cultur scientif',
#  'develop credit agreement detail engin account assist project annex develop credit regul amend',
#  'develop credit agreement highway engin project annex gener condit applic develop credit agreement',
#  'guarante agreement railway project annex gener condit applic loan guarante agreement loan agreement bank national de chemin de fer tunisien',
#  'develop credit agreement railway project annex gener condit applic develop credit agreement',
#  'loan agreement educ project annex loan regul amend',
#  'guarante agreement livestock agricultur develop project annex gener condit applic loan guarante agreement loan agreement bank nacion financiera project agreement bank banco de mexico',
#  'exchang note constitut agreement netherland unit state america relat oblig aris util credit balanc allot netherland within term articl agreement onth establish european payment union septemb',
#  'agreement establish centro internacion de agricultura tropic',
#  'loan agreement second road project annex gener condit applic loan guarante agreement',
#  'develop credit agreement highway engin project annex gener condit applic develop credit agreement',
#  'agreement concern postal servic telecommun',
#  'agreement regul transport good passeng road two countri transit territori',
#  'agreement field tourism',
#  'exchang note constitut agreement prolong valid agreement sofia may',
#  'agreement concern field tourism prolong supplement agreement',
#  'agreement concern establish direct airway connect sofia athen',
#  'air transport agreement',
#  'agreement field tourism two countri',
#  'agreement unit nation leagu arab state',
#  'agreement respect militari assist govern thailand govern unit state america',
#  'exchang note constitut agreement relat disposit surplu equip materi furnish agreement respect militari assist govern thailand govern unit state america',
#  'agreement concern abolit visa develop tourism',
#  'agreement concern establish system',
#  'agreement concern abolit visa',
#  'agreement concern intern road transport',
#  'agreement concern abolit visa',
#  'exchang letter constitut agreement concern facilit travel respect territori rome san marino june',
#  'agreement concern social secur rhine boatmen revis',
#  'agreement concern establish offic organis citi san costa rica',
#  'guarante agreement fifth develop financ corpor project annex gener condit applic loan guarante agreement loan agreement bank industri mine develop bank iran',
#  'loan agreement cypru port project annex gener condit applic loan guarante agreement',
#  'agreement protocol octob regard entri forc agreement',
#  'execut agreement presid republ korea command gener unit state armi forc korea concern interim militari secur matter transit period',
#  'loan agreement livestock develop project annex gener condit applic loan guarante agreement project agreement bank thezambia cattl develop limit',
#  'loan agreement fourth highway project annex gener condit applic loan guarante agreement',
#  'agreement concern headquart african malagasi coffe organ privileg immun french territori',
#  'agreement concern admiss student employe',
#  'convent concern employ resid belgium algerian worker famili',
#  'tax agreement protocol exchang letter',
#  'protocol concern cultur annex exchang letter',
#  'protocol concern technic',
#  'exchang letter constitut technic agreement addi ababa juli',
#  'protocol concern return franc remain french servicemen war victim die buri ussr result follow second world war',
#  'exchang note constitut agreement unit state america itali relat entri payment transport cost relief suppli packag itali',
#  'treati concern legal assist civil famili crimin case',
#  'protocol amend convent',
#  'protocol amend convent juli amend',
#  'protocol amend convent sign london septemb',
#  'protocol amend convent',
#  'convent avoid doubl taxat prevent fiscal evas respect tax incom capit',
#  'protocol amend convent juli amend',
#  'protocol amend convent amend',
#  'european agreement instruct educ nurs',
#  'protocol concern taxat road traffic cross frontier republ austria princip liechtenstein',
#  'invest guaranti agreement relat note',
#  'convent respect tax incom properti',
#  'protocol amend convent juli amend',
#  'amend convent amend',
#  'protocol amend convent amend',
#  'protocol amend convent',
#  'agreement sale agricultur commod',
#  'agreement sale agricultur commod',
#  'memorandum understand scientif technic field water resourc',
#  'exchang note constitut agreement relat reciproc grant author permit licens amateur radio oper either countri oper station countri monaco march pari octob',
#  'agreement concern intern laboratori marin radioact privileg immun agenc within princip',
#  'exchang note constitut agreement unit state america unit kingdom occupi area germani relat entri payment transport cost relief suppli packag unit kingdom occupi area germani',
#  'exchang note constitut agreement concern provis unit state govern republ indonesia basic pilot train aircraft djakarta april',
#  'exchang note constitut agreement extend time period provid articl agreement tokyo april',
#  'exchang note constitut agreement relat exchang note march articl agreement tokyo april',
#  'agreement concern trust territori pacif island sign tokyo april',
#  'exchang note constitut agreement implement articl paragraph agreement washington march',
#  'exchang note constitut agreement deploy uss yosemit uss grand canyon malta valletta june',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement extens loan vessel uss benson uss hilari jone uss plunkett republ china taipei june',
#  'exchang note constitut agreement extend agreement june amend extend agreement june warsaw octob',
#  'agreement regard fisheri western region middl atlant ocean',
#  'exchang note constitut understand establish sheme joint enforc regard fisheri western region middl atlant ocean scheme joint enforc washington octob decemb',
#  'exchang note constitut agreement extend agreement june extend extend amend agreement june extend understand octob decemb establish scheme joint enforc regard fisheri western region middl atlant ocean warsaw june',
#  'agreement regard fisheri western region middl atlant ocean amend extend agreement',
#  'agreement cooper concern civil use atom energi',
#  'agreement cooper concern civil use atom energi',
#  'agreement sale agricultur commod',
#  'exchang note constitut agreement relat peac corp port spain juli',
#  'agreement govern unit state america govern greec entri free inland transport relief suppli packag unit state america greec',
#  'convent regul condit custom union neighbourli relat',
#  'exchang note constitut agreement amend agreement govern unit state america govern greec entri free inland transport relief suppli packag unit state america greec amend',
#  'invest guaranti agreement',
#  'exchang note constitut agreement concern oper pilotag great lake st lawrenc seaway memorandum arrang washington juli',
#  'exchang note constitut agreement concern space activ peac purpos tokyo juli',
#  'understand regard establish oper unit state romania american romanian librari respect bucharest august',
#  'treati friendship mutual assist',
#  'european convent compulsori insur civil liabil respect motor vehicl',
#  'european convent inform foreign law',
#  'addit protocol european convent inform foreign law',
#  'agreement concern intern road transport',
#  'agreement concern establish offic organ manila',
#  'exchang letter constitut agreement concern statu profession aviat school algier april',
#  'exchang note constitut agreement unit state america austria relat entri payment transport cost relief suppli packag austria',
#  'loan agreement road improv project',
#  'exchang letter constitut agreement interpret articl agreement pari may',
#  'agreement concern supplementari pension scheme',
#  'protocol concern particip franc establish administr oper algier nation school engin technician',
#  'agreement concern encourag reciproc protect invest protocol',
#  'agreement regard loan econom develop cambodia annex exchang letter',
#  'agreement supplement hagu convent march relat civil procedur relat law civil procedur',
#  'convent concern maximum permiss weight carri one worker',
#  'supplementari convent regard legal proceed',
#  'loan agreement ninth pakistan railway project annex gener condit applic loan guarante agreement project agreement bank provinc west pakistan',
#  'agreement abolit visa requir',
#  'declar recogn compulsori jurisdict intern court justic conform articl paragraph statut intern court justic gaboron januari',
#  'execut agenc agreement',
#  'agreement unit state america state zone free territori triest free entri free inland transport relief suppli packag',
#  'exchang note constitut agreement amend agreement unit state america state zone free territori triest free entri free inland transport relief suppli packag',
#  'agreement relat seminar role youth promot protect human right held belgrad june',
#  'protocol amend agreement',
#  'agreement econom technic annex schedul',
#  'agreement peac use atom energi',
#  'agreement concern mutual abolit visa travel nation czechoslovak socialist republ nation union soviet socialist republ',
#  'trade agreement annex list',
#  'gener agreement technic addit protocol exchang letter',
#  'exchang note constitut agreement amend agreement amend rome june',
#  'exchang note constitut agreement amend agreement amend rome octob',
#  'exchang note constitut agreement amend agreement amend rome octob decemb',
#  'exchang note constitut agreement amend agreement govern unit state america govern italian republ financ certain educ exchang programm',
#  'execut agenc agreement',
#  'exchang note constitut agreement modifi agreement govern unit state america govern italian republ financ certain educ exchang programm amend',
#  'protocol concern applic chapter agreement sign pari juli',
#  'agreement econom monetari financi matter annex exchang letter',
#  'convent concern relat french treasuri togoles treasuri procedur french republ togoles republ respect organ oper treasuri servic',
#  'protocol settlement real properti question annex exchang letter sign april',
#  'protocol concern construct intern motorway bridg bidassoa vicin biriat',
#  'convent concern construct two intern bridg bidassoa one behobia vicin biriat',
#  'convent scientif technic',
#  'convent concern technic cultur exchang',
#  'exchang note constitut agreement relat consular matter jerusalem februari tel aviv april',
#  'exchang note constitut agreement relat visa port spain decemb',
#  'exchang note constitut agreement unit state america denmark relat exchang offici public',
#  'exchang note constitut agreement amend agreement tel aviv februari',
#  'exchang note constitut agreement avoid doubl taxat incom deriv oper ship aircraft montevideo januari march',
#  'agreement field tourism',
#  'exchang note constitut agreement relat visa athen februari',
#  'exchang note constitut agreement relat mutual issu act civil statu without exact fee tel aviv februari jerusalem march',
#  'exchang note constitut agreement relat visa port loui may',
#  'exchang note constitut agreement relat visa bridgetown june',
#  'agreement concern abolit visa',
#  'exchang note constitut agreement relat visa manila decemb',
#  'exchang letter constitut agreement recogn jurisdict intern labour organis administr tribun unit nation industri develop organ',
#  'exchang note constitut agreement amend agreement govern unit state america imperi govern iran use fund receiv govern unit state america sale surplu properti iran',
#  'agreement govern unit state america imperi govern iran use fund receiv govern unit state america sale surplu properti iran',
#  'exchang note constitut agreement relat visa maseru januari',
#  'exchang letter constitut agreement concern netherland contribut prek thnot power irrig develop project phnom penh june juli',
#  'treati friendship mutual assist czechoslovak socialist republ socialist republ romania',
#  'agreement danish govern loan indonesia annex exchang letter sign djakarta octob',
#  'agreement relat air servic annex exchang letter',
#  'agreement relat air servic schedul exchang letter',
#  'develop loan agreement annex exchang letter',
#  'agreement concern assist unit nation develop programm special fund',
#  'agreement econom industri technic',
#  'agreement seminar realiz econom social right particular refer develop countri',
#  'treati friendship commerc navig unit state america italian republ',
#  'agreement supplement treati sign washingon septemb',
#  'memorandum understand mainten american read room yugoslavia',
#  'agreement cultur exchang',
#  'exchang note constitut agreement program exchang educ scientif cultur field enclosur washington novemb',
#  'exchang note constitut agreement concern custom regul cargo unit state militari forc manila april',
#  'exchang letter constitut agreement continu applic singapor unit kingdom treati decemb concern extradit singapor april june',
#  'exchang note constitut agreement concern statu foreign servic institut school languag area studi taichung personnel taipei juli',
#  'exchang note constitut agreement concern trade cotton textil washington august',
#  'exchang note constitut agreement concern reciproc advanc fund temporari support arm forc personnel wellington septemb',
#  'exchang note constitut agreement use special fund educ philippin scienc high school project manila septemb',
#  'exchang note constitut agreement continu applic convent republ austria unit kingdom regard legal proceed civil commerci matter sign london march bangkok august januari',
#  'convent unit state america republ costa rica establish tropic tuna commiss',
#  'convent determin fish zone reserv respect french italian fishermen water corsica sardinia',
#  'technic assist agreement supplement agreement',
#  'agreement dual nation',
#  'cultur exchang agreement',
#  'declar recogn compulsori jurisdict intern court justic conform articl paragraph statut intern court justic new york april',
#  'intern convent standard method wine analysi evalu annex',
#  'protocol amend treati',
#  'treati concern legal assist civil famili crimin case',
#  'convent establish intern sericultur commiss open signatur pari juli decemb',
#  'execut agenc agreement',
#  'exchang note constitut agreement australia finland concern releas money belong person resid finland held cash control enemi properti australia settlement australian claim finland aris second world war',
#  'trade agreement annex list',
#  'health servic convent',
#  'fourth protocol amend convent may',
#  'protocol amend convent sign london june',
#  'protocol amend convent amend',
#  'protocol amend convent sign london june',
#  'supplementari protocol amend convent modifi protocol sign london februari',
# ...
#  'exchang note constitut agreement amend annex b agreement luxembourg june',
#  'exchang note constitut agreement amend annex b mutual defens assist agreement unit state america luxembourg',
#  'exchang note constitut agreement amend annex b agreement luxembourg may',
#  'exchang note constitut agreement amend annex b mutual defens assist agreement unit state america luxembourg',
#  'contract leas enrich uranium research reactor chile',
#  'letter agreement constitut extens contract leas enrich uranium research reactor chile decemb',
#  'letter agreement extend contract leas enrich uranium research reactor chile',
#  'agreement assist agenc chile establish research reactor project annex',
#  'contract transfer enrich uranium research reactor indonesia',
#  'agreement assist agenc indonesia continu reactor project',
#  'amend agreement decemb',
#  'agreement relat provis assist develop countri sign vienna decemb',
#  'agreement econom industri technic',
#  'agreement concern abolit visa',
#  'exchang note constitut agreement confirm arrang may concern creation dudelang luxembourg territori joint frontier control bureau map pari june',
#  'exchang note constitut agreement confirm arrang concern creation schengen luxembourg territori joint frontier control bureau pari novemb',
#  'convent relat adjoin nation control offic inspect move vehicl',
#  'convent concern deposit consign effect gabon',
#  'mutual defens assist agreement govern unit state america govern republ korea',
#  'execut agenc agreement',
#  'agreement econom industri technic',
#  'exchang note constitut agreement rectifi agreement belgrad novemb decemb',
#  'convent concern plant protect phytosanitari control',
#  'exchang letter constitut agreement concern establish quarantin station miquelon ottawa april',
#  'agreement concern establish french librari bucharest romanian librari pari',
#  'special agreement concern second militari personnel',
#  'exchang letter constitut agreement amend agreement bujumbura may june',
#  'agreement movement person',
#  'agreement movement person',
#  'agreement govern french republ govern togoles republ movement person',
#  'agreement concern air servic',
#  'agreement concern intern transport good road',
#  'mutual defens assist agreement unit state america netherland',
#  'loan agreement second technolog advanc project',
#  'convent avoid doubl taxat prevent fiscal evas respect tax incom',
#  'agreement assist india institut speech hear mysor',
#  'agreement danish govern loan turkey annex exchang letter',
#  'agreement concern establish offic organis djakarta',
#  'loan highway project annex gener condit applic loan guarante agreement',
#  'develop credit highway project annex gener condit applic develop credit agreement',
#  'loan agreement second educ project annex gener condit applic loan guarante agreement',
#  'guarante agreement second telecommun project annex gener condit applic loan guarante agreement loan agreement bank singapor telephon board',
#  'guarante agreement industri project annex gener condit applic loan guarante agreement loan agreement bank andth yugoslav invest bank',
#  'exhang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exchang note constitut agreement amend annex c agreement oslo decemb',
#  'exchang note constitut agreement extend agreement april may oslo novemb januari',
#  'exchang note constitut agreement amend annex c agreement oslo august septemb',
#  'exchang note constitut agreement amend annex c mutual defens assist agreement unit state america norway amend',
#  'exchang note constitut agreement relat mutual defenc assist agreement unit state america norway amend extend concern loan seaplan tender govern unit state america govern norway defens purpos',
#  'exchang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exchang note constitut agreement amend annex c agreement oslo novemb',
#  'exchang note constitut agreement amend mutual defens assist agreement unit state america norway',
#  'exhang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exchang note constitut agreement amend annex c agreement oslo septemb',
#  'exchang note constitut agreement amend mutual defens assist agreement unit state america norway',
#  'loan agreement univers scienc technolog research project schedul gener condit applic loan guarante agreement januari',
#  'exchang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exhang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exchang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exchang note constitut agreement amend annex c agreement amend august',
#  'exchang note constitut agreement amend annex c agreement amend oslo novemb',
#  'exchang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exchang note constitut agreement amend annex c agreement oslo august septemb',
#  'exchang note constitut agreement amend annex c agreement amend oslo novemb decemb',
#  'exhang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exchang note constitut agreement amend annex c agreement oslo octob',
#  'exchang note constitut agreement amend annex c agreement oslo novemb',
#  'exchang note constitut agreement amend annex c agreement oslo novemb decemb',
#  'exchang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exchang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exchang note constitut agreement amend annex c mutual defens assist agreement unit state america norway amend',
#  'exchang note constitut agreement amend annex c mutual defens assist agreement unit state america norway',
#  'exchang letter constitut agreement concern establish mix commiss econom industri commerci brussel march',
#  'convent belgium greec avoid doubl taxat regul certain matter respect tax incom',
#  'trade agreement sign copenhagen decemb',
#  'exchang letter constitut agreement franc brazil concern film',
#  'addit protocol agreement',
#  'agreement concern intern road transport',
#  'amend agreement march',
#  'agreement concern field tourism',
#  'exchang note constitut agreement danish assist establish institut milk technolog valdivia santiago januari',
#  'loan third cukurova power project annex gener condit applic loan guarante agreement project agreement bank cukurova elektrik',
#  'exchang note constitut agreement concern weapon product programm accord term condit mutual defens assist agreement etween unit state america unit kingdom great britain northern ireland',
#  'exchang note constitut agreement relat disposit equip materi furnish mutual defens assist agreement unit state america unit kingdom great britain northern ireland',
#  'exchang note constitut agreement amend agreement unit state america unit kingdom great britain northern ireland relat disposit equip materi furnish mutual defens assist agreement januari two countri',
#  'mutual defens assist agreement unit state america unit kingdom great britain northern ireland',
#  'loan agreement juam region water suppli project',
#  'exchang note constitut agreement amend agreement relat disposit equip materi furnish mutual defens assist agreement unit state america unit kingdom great britain northern ireland',
#  'exchang note constitut agreement amend agreement may unit state america unit kingdom great britain northern ireland relat disposit equip materi furnish mutual defens assist agreement januari two countri',
#  'treati friendship mutual assist czechoslovak socialist republ union soviet socialist republ',
#  'trade econom agreement',
#  'protocol addit agreement',
#  'convent belgium peru concern technic scientif',
#  'guarante agreement process project annex loan regul amend loan agreement bank palmindustri palmivoir',
#  'agreement amend agreement sign washington septemb',
#  'agreement applic safeguard connect treati nuclear weapon',
#  'exchang note constitut agreement unit state america iran relat mutual defens assist',
#  'exchang note constitut agreement relat disposit militari equip materi furnish agreement unit state america iran relat mutual defens assist',
#  'develop credit agreement north sumatra agricultur estat project annex gener condit applic develop credit agreement',
#  'develop credit agreement highway project annex gener condit applic develop credit agreement',
#  'develop credit agreement highway mainten project annex gener condit applic develop credit agreement',
#  'develop credit agreement water suppli sewerag project annex gener condit applic develop credit agreement project agreement associ ghana water sewerag corpor',
#  'develop credit agreement tenth railway project annex gener condit applic develop credit agreement',
#  'convent avoid doubl taxat prevent fiscal evas respect tax incom',
#  'agreement concern donat toward execut prek thnot power irrig develop project',
#  'exchang note constitut agreement convey hous hut eastern greenland danish govern oslo april',
#  'agreement concern abolit passport visa fee',
#  'exchang note constitut agreement netherland luxembourg regard placement netherland agricultur worker luxembourg',
#  'execut agenc agreement',
#  'develop credit agreement educ project annex gener condit applic develop credit agreement',
#  'agreement amend agreement',
#  'develop credit agreement telecommun project annex gener condit applic develop credit agreement',
#  'develop credit agreement drainag reclam project annex gener condit applic develop credit agreement',
#  'develop credit agreement wolamo agricultur projet annex gener condit applic develop credit agreement',
#  'agreement transit transport good passeng territori well transport two countri protocol exchang letter',
#  'transit agreement protocol exchang letter',
#  'agreement regard statu personnel send state attach intern militari headquart nato feder republ germani',
#  'agreement regard make avail arm forc unit kingdom great britain northern ireland unit state america accommod intern militari headquart nato feder republ germani',
#  'develop credit agreement technic administr project annex gener condit applic develop credit agreement',
#  'develop credit agreement second road project annex gener condit applic develop credit agreement',
#  'agreement concern exchang commod kingdom denmark polish republ',
#  'agreement applic safeguard connect treati nuclear weapon',
#  'convent avoid doubl taxat respect tax incom',
#  'develop credit agreement fisheri project annex gener condit applic develop credit agreement project agreement associ ghana industri hold corpor',
#  'standard agreement oper assist',
#  'revis standard agreement technic assist sign new york juli',
#  'agreement purpos avoid doubl taxat incom deriv busi sea air transport',
#  'loan agreement mechan farm project annex loan regul amend',
#  'loan agreement boke project annex loan regul amend',
#  'guarante agreement third bnde project annex loan regul amend loan agreement bank banqu national pour le',
#  'guarante agreement second port project annex loan regul amend loan agreement bank offic de port nationaux tunisien',
#  'agreement intern carriag good road',
#  'agreement unit state america turkey concern aid turkey',
#  'agreement concern settlement payment denmark poland',
#  'agreement regard execut intern develop activ',
#  'addit protocol payment agreement kingdom denmark polish republ date',
#  'exchang note constitut agreement concern develop loan govern unit kingdom great britain northern ireland govern ecuador unit loan quito novemb',
#  'exchang note constitut agreement amend agreement quito decemb june',
#  'agreement concern legal assist civil matter concern offici document protocol exchang note april ocrob',
#  'convent avoid doubl taxat prevent fiscal evas respect tax incom capit',
#  'convent avoid doubl taxat prevent fiscal evas respect tax incom capit',
#  'exchang note constitut agreement extend agreement helsinki may',
#  'agreement concern fish seal annex exchang note',
#  'exchang note constitut agreement amend agreement sign helsinki may',
#  'agreement belgium iceland avoid doubl taxat incom airlin',
#  'supplementari agreement concern termin aagreement unit nation govern peru govern sweden provis technic cadr unit swedish forc unit nation servic assist reconstruct area peru devast result earthquak occur may',
#  'modu operandi implement agreement unit nation govern peru govern sweden provis technic cadr unit swedish forc unit nation servic assist reconstruct area peru devast result earthquak occur may',
#  'agreement unit nation govern peru govern sweden provis technic cadr unit swedish forc unit nation servic assist reconstruct area peru devast result earthquak occur may',
#  'agreement relat contribut french govern establish oper algerian petroleum institut',
#  'protocol concern exchang good settlement payment denmark poland period octob septemb',
#  'agreement concern settlement question relat hydrocarbon industri develop algeria protocol annex exchang letter',
#  'agreement air servic beyond respect territori',
#  'protocol authent trilingu text convent intern civil aviat chicago annex rectif april',
#  'exchang note constitut agreement amend agreement amend saigon may',
#  'supplementari agreement sale agricultur commod',
#  'exchang note constitut agreement amend agreement amend saigon june',
#  'supplementari agreement sale agricultur commod',
#  'exchang note constitut agreement concern provis instal certain distanc measur equip plaisanc airfield mauritiu fort loui novemb decemb',
#  'agreement concern establish unit state naval medic research unit indonesia',
#  'exchang note constitut agreement concern export new zealand import unit state certain specifi meat washington decemb',
#  'exchang note constitut agreement relat import meat unit state consumpt calendar year washington januari',
#  'exchang note constitut agreement relat import unit state meat calendar year washington januari',
#  'exchang note constitut agreement concern export australia import unit state certain specifi meat washington decemb',
#  'exchang note constitut agreement concern export ireland import unit state certain specifi meat washington decemb',
#  'exchang note constitut agreement relat import meat unit state consumpt calendar year washington januari',
#  'basic agreement establish technic advisori cooper relat',
#  'treati friendship kingdom thailand republ philippin',
#  'agreement unit state america malaysia amend air transport agreement februari amend',
#  'agreement unit state america malaysia amend air transport agreement februari amend',
#  'exchang note constitut agreement amend agreement memorandum consult juli kuala lumpur septemb februari',
#  'agreement unit state america malaysia amend air servic agreement februari amend',
#  'air transport agreement govern unit state america govern malaysia',
#  'exchang letter constitut agreement amend agreement februari',
#  'agreement financ certain educ cultur exchang program',
#  'exchang note constitut agreement provid framework assist unit state america small develop activ republ burundi bujumbura februari',
#  'exchang note constitut agreement relat use certain facil unit state air forc pinetre radar site hopedal labrador canada ottawa june septemb februari',
#  'agreement unit state america norway amend agreement februari relat safeguard classifi inform',
#  'exchang note constitut agreement relat safeguard classifi inform',
#  'exchang note constitut agreement concern preparatori measur transfer administr right okinawa japan tokyo march',
#  'exchang note constitut agreement relat import meat unit state consumpt calendar year panama februari march',
#  'exchang note constitut agreement relat import meat unit state consumpt calendar year san march',
#  'exchang letter constitut agreement relat agreement san juli',
#  'second supplementari agreement sale agricultur commod']

# %%
plt.figure(figsize = (14,7))
# Construct a word cloud from corpus.
wordcloud = WordCloud(max_font_size = 40,
                      background_color = "white",
                      collocations = False) # if true, we will look into n-grams

wordcloud = wordcloud.generate(' '.join(titles_clean_list))

# Plot the cloud using matplotlib.
plt.figure()
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off")

# Plot the cloud using matplotlib.
plt.figure(figsize = (27, 20))
plt.imshow(wordcloud, interpolation = "bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# #### Task 1
# ##### Check the length of `processed_docs_ex` using `len()` function.
# ##### Create a dictionary from `processed_docs_ex` object, using `gensim.corpora.Dictionary` function.
# ##### Label the dictionary `dictionary_ex`.
# ##### Then loop through the dictionary printing out the first 10 items, including key and value.
# ##### Make sure to set the seed as `2` for exercises.
# ##### Use `.filter_extremes()` to filter items. Set `no_below` as `5`, `no_above` as `0.5` and `keep_n` as `942`.

# %% [markdown]
# - Hint:
# To check the length, use `len(processed_docs_ex)`.

# %% [markdown]
# #### Result:

# %% [markdown]
# #### Task 2
# ##### Write a list comprehension that transforms each doc within the `processed_docs_ex` .
# ##### Save this object, the output of the list comprehension, as `bow_corpus_ex`.
# ##### What type of object is this?

# %% [markdown]
# #### Result:

# %% [markdown]
# #### Task 3
# ##### Transform `bow_corpus_ex` to a TF-IDF transformed object using `TfIdfModel()`.
# ##### Name the object as `corpus_tfidf_ex`.
# ##### Preview the scores for the first document in `corpus_tfidf_ex` using `pprint`.

# %% [markdown]
# #### Result:

# %% [markdown]
# #### Task 4
# ##### Pickle `bow_corpus_ex`, `corpus_tfidf_ex` and `dictionary_ex` for the next session.

# %% [markdown]
# #### Result:
